# %%
# !pip install pysus
# Out:
# ...
#      |████████████████████████████████| 3.2MB 7.4MB/s
# ...
#      |████████████████████████████████| 102kB 8.4MB/s
# ...
#      |████████████████████████████████| 28.6MB 150kB/s
# ...
#      |████████████████████████████████| 61kB 8.1MB/s
# ...
#   Created wheel for pysus: filename=PySUS-0.4.8-cp36-cp36m-linux_x86_64.whl size=1384445 sha256=4bade903ab443e3fad4e96f154f2ad4af94c0d4fb837b89cee058bbdaf9908a5
#   Stored in directory: /root/.cache/pip/wheels/bf/06/65/2d6e4175e25a37bf05a96b83aa5e7ce6b50f905ecc1181b913
# ...
#   Created wheel for fastparquet: filename=fastparquet-0.4.1-cp36-cp36m-linux_x86_64.whl size=7125488 sha256=4be13d02b29f242c9738cd02175b016543c43c057039b1387ccf276f7e913a88
#   Stored in directory: /root/.cache/pip/wheels/10/45/cf/492ccb908adde1dd2551bb509a56e4096cce9487167f525120
# ...
#   Created wheel for thrift: filename=thrift-0.13.0-cp36-cp36m-linux_x86_64.whl size=345221 sha256=0f665606de94147f620794c4e4b02f8d25108cf3af63b919cc5eb3f81c74a906
# ...

# %%
from pysus.online_data.sinasc import download

# %%
df = download('SE', 2015)

# %%
df.head()
# Out:
#   contador ORIGEM CODESTAB CODMUNNASC  ... CODPAISRES TPROBSON PARIDADE KOTELCHUCK
# 0        1      1              280510  ...                  11        1          9
# 1        2      1              280270  ...                  11        1          9
# 2        3      1              280440  ...                  11        1          5
# 3        4      1  2421534     280440  ...                  10        1          3
# 4        5      1  2799782     291650  ...                  03        1          2
#
# [5 rows x 61 columns]

# %%
from pysus.online_data.SIM import download

# %%
df = download('ba', 2007)

# %%
df.head()
# Out:
#   CONTADOR TIPOBITO   DTOBITO HORAOBITO  ... FONTEINV DTRECEBIM UFINFORM CB_PRE
# 0        1        2  30072007      1130  ...           19102007       29   C229
# 1        2        2  04072007      1140  ...           19102007       29    R98
# 2        3        2  25082007      1500  ...           19102007       29    I10
# 3        4        2  11092007      1820  ...           19102007       29   G839
# 4        5        2  09082007      1640  ...           24102007       29   I499
#
# [5 rows x 54 columns]
